# %% [markdown]
# <a href="https://colab.research.google.com/github/andreamurari/T_one_sellout_24/blob/main/report_T_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
IT_1=pd.read_excel("/content/sell_out_01_gennaio_2024_vs_2023.xlsx", sheet_name="IT")
AMP_1=pd.read_excel("/content/sell_out_01_gennaio_2024_vs_2023.xlsx", sheet_name="complessivo")
IT_2=pd.read_excel("/content/sell_out_02_febbraio_2024_vs_2023.xlsx", sheet_name="IT")
AMP_2=pd.read_excel("/content/sell_out_02_febbraio_2024_vs_2023.xlsx", sheet_name="complessivo")
IT_3=pd.read_excel("/content/sell_out_03_marzo_2024_vs_2023.xlsx", sheet_name="IT")
AMP_3=pd.read_excel("/content/sell_out_03_marzo_2024_vs_2023.xlsx", sheet_name="Complessivo")
IT_T=pd.read_excel("/content/sellout_annuale_1T.xlsx", sheet_name="analisi_IT")
AMP_T=pd.read_excel("/content/sellout_annuale_1T.xlsx", sheet_name="analisi_ALL_MP")
EXT_T=pd.read_excel("/content/sellout_annuale_1T.xlsx", sheet_name="analisi_IT")
SUMMARY=pd.read_excel("/content/sellout_annuale_1T.xlsx", sheet_name="analisi_ALL_MP")
